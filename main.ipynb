# %%
import pandas as pd
from datasets import load_dataset

# %%
# download data from huggingface
newsqa = load_dataset("lucadiliello/newsqa")
newsqa["train"].to_parquet("data/raw/newsqa_train.parquet")
newsqa["validation"].to_parquet("data/raw/newsqa_validation.parquet")
# Out:
# Creating parquet from Arrow format:   0%|          | 0/75 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# 13234462

# %%
# load data
newsqa_train = pd.read_parquet("data/raw/newsqa_train.parquet")
newsqa_validation = pd.read_parquet("data/raw/newsqa_validation.parquet")
newsqa = pd.concat([newsqa_train, newsqa_validation])

# format answers and drop irrelevant columns
newsqa["answers"] = newsqa["answers"].apply(lambda x: x[0])
newsqa = newsqa.drop(columns=["key", "labels"])
newsqa.columns = ["context", "questions", "answers"]
newsqa
# Out:
#                                                 context  \
# 0     NEW DELHI, India (CNN) -- A high court in nort...
# 1     NEW DELHI, India (CNN) -- A high court in nort...
# 2     NEW DELHI, India (CNN) -- A high court in nort...
# 3     NEW DELHI, India (CNN) -- A high court in nort...
# 4     NEW DELHI, India (CNN) -- A high court in nort...
# ...                                                 ...
# 4207  WASHINGTON (CNN) -- President Obama on Friday ...
# 4208  NEW YORK (CNN) -- John and Elizabeth Calvert e...
# 4209  NEW YORK (CNN) -- John and Elizabeth Calvert e...
# 4210  NEW YORK (CNN) -- John and Elizabeth Calvert e...
# 4211  NEW YORK (CNN) -- John and Elizabeth Calvert e...
#
#                                               questions  \
# 0             What was the amount of children murdered?
# 1                  When was Pandher sentenced to death?
# 2     The court aquitted Moninder Singh Pandher of w...
# 3                                     who was acquitted
# 4                                     who was sentenced
# ...                                                 ...
# 4207                  What will the new system include?
# 4208                                   who are growing?
# 4209                         Where did the couple live?
# 4210      when was the last seen of John and Elizabeth?
# 4211                       Who were they suspicious of?
#
#                                                 answers
# 0                                                    19
# 1                                             February.
# 2                                       rape and murder
# 3                                Moninder Singh Pandher
# 4                                Moninder Singh Pandher
# ...                                                 ...
# 4207  give detainees greater latitude in selecting l...
# 4208                                            friends
# 4209                                 Hilton Head Island
# 4210                                           March 3,
# 4211                                 Dennis Ray Gerwing
#
# [78372 rows x 3 columns]

# %%
# group by context
newsqa = newsqa.groupby("context").agg(
    {
        "questions": lambda x: list(x),
        "answers": lambda x: list(x),
    }
)
newsqa = newsqa.reset_index()
newsqa
# Out:
#                                                  context  \
# 0      "Everything can be improved." -- Ross Lovegrov...
# 1      'SINDH KALAY', England (CNN) -- The aroma of f...
# 2      (AOL Autos)  -- At the 2009 Detroit Auto Show,...
# 3      (AOL Autos)  -- Buying a used car may seem lik...
# 4      (AOL Autos)  -- Collecting cars is an expensiv...
# ...                                                  ...
# 11470  Yazoo City, Mississippi (CNN) -- Rescue crews ...
# 11471  You wanted to know more about greenwashing, an...
# 11472  ZURICH, Switzerland (CNN) -- As I watched Cris...
# 11473  iReporter Doranne Lim chronicles the flooding ...
# 11474  • The twins get a check-up (2/26/08) • VIDEO: ...
#
#                                                questions  \
# 0      [Who is Ross Lovegrove?, Where is his work hel...
# 1      [Where were they being deployed to?, What does...
# 2      [What debuts at the 2009 Detroit Auto Show?, W...
# 3      [What does Texas have?, What will the average ...
# 4      [What can compete with the Mercedes SL Class?,...
# ...                                                  ...
# 11470  [Where did two sisters die?, What day were tor...
# 11471  [Who is answering the questions on greenwashin...
# 11472  [Who won the FIFA Player of the Year for 2008 ...
# 11473  [Did the earthquake cause the tsunami?, What l...
# 11474  [Pictures are of whom?, Who was born November ...
#
#                                                  answers
# 0      [Designer, in permanent collections of various...
# 1      [Afghanistan's Helmand province, how the peopl...
# 2      [electric vehicles, Chrysler, Mercedes-Benz, T...
# 3      [has more used vehicles than any other state, ...
# 4      [Cadillac XLR-V, hatchback,, hatchback,, editi...
# ...                                                  ...
# 11470  [inside a mobile home, Choctaw County, Saturda...
# 11471  [Scot Case,, green, Scot Case,, green products...
# 11472  [Cristiano Ronaldo, Cristiano Ronaldo, Cristia...
# 11473  [waves triggered by an 8.0, Tsunami, Pasig Cit...
# 11474  [Nancy Grace's twins, Nancy Grace's twins, Nan...
#
# [11475 rows x 3 columns]

# %%
# create the question-answer column
newsqa["questions_answers"] = newsqa.apply(
    lambda x: " | ".join(
        [
            f"question: {question}, answer: {answer}"
            for question, answer in zip(x["questions"], x["answers"])
        ]
    ),
    axis=1,
)
newsqa
# Out:
#                                                  context  \
# 0      "Everything can be improved." -- Ross Lovegrov...
# 1      'SINDH KALAY', England (CNN) -- The aroma of f...
# 2      (AOL Autos)  -- At the 2009 Detroit Auto Show,...
# 3      (AOL Autos)  -- Buying a used car may seem lik...
# 4      (AOL Autos)  -- Collecting cars is an expensiv...
# ...                                                  ...
# 11470  Yazoo City, Mississippi (CNN) -- Rescue crews ...
# 11471  You wanted to know more about greenwashing, an...
# 11472  ZURICH, Switzerland (CNN) -- As I watched Cris...
# 11473  iReporter Doranne Lim chronicles the flooding ...
# 11474  • The twins get a check-up (2/26/08) • VIDEO: ...
#
#                                                questions  \
# 0      [Who is Ross Lovegrove?, Where is his work hel...
# 1      [Where were they being deployed to?, What does...
# 2      [What debuts at the 2009 Detroit Auto Show?, W...
# 3      [What does Texas have?, What will the average ...
# 4      [What can compete with the Mercedes SL Class?,...
# ...                                                  ...
# 11470  [Where did two sisters die?, What day were tor...
# 11471  [Who is answering the questions on greenwashin...
# 11472  [Who won the FIFA Player of the Year for 2008 ...
# 11473  [Did the earthquake cause the tsunami?, What l...
# 11474  [Pictures are of whom?, Who was born November ...
#
#                                                  answers  \
# 0      [Designer, in permanent collections of various...
# 1      [Afghanistan's Helmand province, how the peopl...
# 2      [electric vehicles, Chrysler, Mercedes-Benz, T...
# 3      [has more used vehicles than any other state, ...
# 4      [Cadillac XLR-V, hatchback,, hatchback,, editi...
# ...                                                  ...
# 11470  [inside a mobile home, Choctaw County, Saturda...
# 11471  [Scot Case,, green, Scot Case,, green products...
# 11472  [Cristiano Ronaldo, Cristiano Ronaldo, Cristia...
# 11473  [waves triggered by an 8.0, Tsunami, Pasig Cit...
# 11474  [Nancy Grace's twins, Nancy Grace's twins, Nan...
#
#                                        questions_answers
# 0      question: Who is Ross Lovegrove?, answer: Desi...
# 1      question: Where were they being deployed to?, ...
# 2      question: What debuts at the 2009 Detroit Auto...
# 3      question: What does Texas have?, answer: has m...
# 4      question: What can compete with the Mercedes S...
# ...                                                  ...
# 11470  question: Where did two sisters die?, answer: ...
# 11471  question: Who is answering the questions on gr...
# 11472  question: Who won the FIFA Player of the Year ...
# 11473  question: Did the earthquake cause the tsunami...
# 11474  question: Pictures are of whom?, answer: Nancy...
#
# [11475 rows x 4 columns]

# %%
# generate train, validation and test sets
len_newsqa = len(newsqa)
val_split = 0.05
test_split = 0.05

index_val = int(len_newsqa * (1 - val_split - test_split))
index_test = int(len_newsqa * (1 - test_split))

newsqa_train = newsqa.iloc[:index_val]
newsqa_validation = newsqa.iloc[index_val:index_test]
newsqa_test = newsqa.iloc[index_test:]

# %%
# save data
newsqa_train.to_parquet("data/processed/newsqa_train.parquet")
newsqa_validation.to_parquet("data/processed/newsqa_validation.parquet")
newsqa_test.to_parquet("data/processed/newsqa_test.parquet")
